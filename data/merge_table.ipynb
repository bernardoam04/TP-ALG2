# %%
import pandas as pd
import re
from unidecode import unidecode
from rapidfuzz import process, fuzz

# %%
def normaliza_texto(texto):
    texto = unidecode(str(texto)).lower()
    texto = re.sub(r"\'s|\’s", "", texto)  # remove possessivos como "buteco's"
    texto = texto.replace('-', ' ')
    texto = re.sub(r'[^\w\s]', '', texto)  # remove pontuação restante
    return texto.strip()
def extrai_complemento(texto):
    if pd.isna(texto):
        return ''
    
    #Tenta encontrar sequência de números que identifiquem unicamente
    match_num = re.search(r'\d+', texto)
    if(match_num):
        return match_num.group(0)
    
    #Caso contrário, busca por uma letra isolada Ex: {Bloco B} -> {B}
    match_letra = re.search(r'\b([a-zA-Z])\b', texto)
    if(match_letra):
        return match_letra.group(1)
    
    #Se chegou até aqui, não deu match algum
    return ''


def encontrar_correspondencia(chave, chaves_possiveis, limiar=90):
    correspondencia, score, _ = process.extractOne(chave, chaves_possiveis, scorer=fuzz.token_sort_ratio)
    if score >= limiar:
        return correspondencia
    return None

# %%
# Carrega os arquivos
df_completo = pd.read_csv("20250401_atividade_economica_coord.csv", sep=';')
df_buteco = pd.read_csv("bares_cdb.csv")

# %%
# Pré-processamento do endereço
df_buteco["logradouro"] = df_buteco["Endereco"].str.split(r" \| ").str[0]
df_buteco[["rua", "numero"]] = df_buteco["logradouro"].str.extract(r"^\S+\s+(.*),\s*(\d+)")
df_buteco['comp'] = df_buteco['Complemento'].apply(extrai_complemento)

# %%
#Limpar os dados para facilitar no processamento
colunas_necessarias = [
    'ID_ATIV_ECON_ESTABELECIMENTO',
    'NOME_LOGRADOURO',
    'NUMERO_IMOVEL',
    'COMPLEMENTO',
    'NOME',
    'NOME_FANTASIA'
]

df_reduzido = df_completo[colunas_necessarias].copy()
df_reduzido['comp'] = df_reduzido['COMPLEMENTO'].apply(extrai_complemento)

# %%
#Cria as chaves para comparação

df_reduzido['chave'] = (
    df_reduzido['NOME_LOGRADOURO'].apply(normaliza_texto) + 
    '|' + 
    df_reduzido['NUMERO_IMOVEL'].astype(str) +
    '|' +
    df_reduzido['comp'].apply(normaliza_texto)
)

df_buteco['chave'] = (
    df_buteco['rua'].apply(normaliza_texto) +
    '|' +
    df_buteco['numero'].apply(normaliza_texto) +
    '|' +
    df_buteco['comp'].apply(normaliza_texto)
)

df_buteco['chave_casada'] = df_buteco['chave'].apply(
    lambda x: encontrar_correspondencia(x, df_reduzido['chave'])
)

# %%
#Casa os dataframes pela chave fuzzy
df_merge = df_buteco.merge(
    df_reduzido,
    left_on='chave_casada',   
    right_on='chave',         
    how='left',
    suffixes=('_buteco', '_completo'),
    indicator=True
)
# Out:
#                   Nome                                      Link Detalhes  \
# 0      Alexandre’s Bar  https://comidadibuteco.com.br/buteco/alexandre...
# 1    Amarelim do Prado  https://comidadibuteco.com.br/buteco/amarelim-...
# 2       Andrade’s Beer  https://comidadibuteco.com.br/buteco/andrades-...
# 3            Arcos Bar    https://comidadibuteco.com.br/buteco/arcos-bar/
# 4            Arcos Bar    https://comidadibuteco.com.br/buteco/arcos-bar/
# ..                 ...                                                ...
# 136  Xico do Churrasco  https://comidadibuteco.com.br/buteco/xico-do-c...
# 137  Xico do Churrasco  https://comidadibuteco.com.br/buteco/xico-do-c...
# 138  Xico do Churrasco  https://comidadibuteco.com.br/buteco/xico-do-c...
# 139         Zé Bolacha   https://comidadibuteco.com.br/buteco/ze-bolacha/
# 140            Zoo Bar      https://comidadibuteco.com.br/buteco/zoo-bar/
#
#               Nome Petisco                                          Descricao  \
# 0        O fabuloso discão  Polpetone com recheio de muçarela acompanhada ...
# 1            Trem de roças  Bochecha de porco na cama de angu mole, pesto ...
# 2          Chora canelinha  Ossobuco com purê de batatas, acompanhado de t...
# 3    Panela da Diversidade  Acém cozido com ervas finas, acompanhado com b...
# 4    Panela da Diversidade  Acém cozido com ervas finas, acompanhado com b...
# ..                     ...                                                ...
# 136            Xico Balaio       Asinhas de frango com provolone com tempero.
# 137            Xico Balaio       Asinhas de frango com provolone com tempero.
# 138            Xico Balaio       Asinhas de frango com provolone com tempero.
# 139                 Rabicó  Bolinho de costelinha desfiada com requeijão e...
# 140    Canjiquinha da Vovó  Canjiquinha à moda da vovó, acompanhada de cos...
#
#                                               Endereco Complemento  \
# 0    Rua David Alves do Vale, 68 | Santa Rosa, Belo...     Loja 01
# 1    Avenida Francisco Sá, 658 | Prado, Belo Horizo...         NaN
# 2    Rua Dona Geni, 32 | Jardim Florência (Venda No...         NaN
# 3     Rua da Bahia, 1144 | Centro, Belo Horizonte – MG      Loja 5
# 4     Rua da Bahia, 1144 | Centro, Belo Horizonte – MG      Loja 5
# ..                                                 ...         ...
# 136  Av Altamiro avelino Soares, 920 | Castelo, Bel...         NaN
# 137  Av Altamiro avelino Soares, 920 | Castelo, Bel...         NaN
# 138  Av Altamiro avelino Soares, 920 | Castelo, Bel...         NaN
# 139  Rua das Melancias, 35 | Vila Cloris, Belo Hori...         NaN
# 140  Avenida Otacílio Negrão de Lima, 7844 | Pampul...         NaN
#
#                                 logradouro                      rua numero  \
# 0              Rua David Alves do Vale, 68      David Alves do Vale     68
# 1                Avenida Francisco Sá, 658             Francisco Sá    658
# 2                        Rua Dona Geni, 32                Dona Geni     32
# 3                       Rua da Bahia, 1144                 da Bahia   1144
# 4                       Rua da Bahia, 1144                 da Bahia   1144
# ..                                     ...                      ...    ...
# 136        Av Altamiro avelino Soares, 920  Altamiro avelino Soares    920
# 137        Av Altamiro avelino Soares, 920  Altamiro avelino Soares    920
# 138        Av Altamiro avelino Soares, 920  Altamiro avelino Soares    920
# 139                  Rua das Melancias, 35            das Melancias     35
# 140  Avenida Otacílio Negrão de Lima, 7844  Otacílio Negrão de Lima   7844
#
#     comp_buteco  ...                   chave_casada  \
# 0            01  ...      david alves do vale|68|01
# 1                ...              francisco sa|658|
# 2                ...                  dona geni|32|
# 3             5  ...                da bahia|1144|5
# 4             5  ...                da bahia|1144|5
# ..          ...  ...                            ...
# 136              ...   altamiro avelino soares|920|
# 137              ...   altamiro avelino soares|920|
# 138              ...   altamiro avelino soares|920|
# 139              ...             das melancias|35|3
# 140              ...  otacilio negrao de lima|7844|
#
#     ID_ATIV_ECON_ESTABELECIMENTO          NOME_LOGRADOURO NUMERO_IMOVEL  \
# 0                        22799.0      DAVID ALVES DO VALE          68.0
# 1                       324006.0             FRANCISCO SA         658.0
# 2                       230593.0                DONA GENI          32.0
# 3                       351721.0                 DA BAHIA        1144.0
# 4                       228827.0                 DA BAHIA        1144.0
# ..                           ...                      ...           ...
# 136                     419351.0  ALTAMIRO AVELINO SOARES         920.0
# 137                     171880.0  ALTAMIRO AVELINO SOARES         920.0
# 138                     372777.0  ALTAMIRO AVELINO SOARES         920.0
# 139                     102948.0            DAS MELANCIAS          35.0
# 140                      50619.0  OTACILIO NEGRAO DE LIMA        7844.0
#
#      COMPLEMENTO                                               NOME  \
# 0        LOJA 01  ALEXANDRE MOREIRA DE AZEVEDO - CPF: 047.878.19...
# 1            NaN                JANUARIO COMERCIO DE ALIMENTOS LTDA
# 2            NaN          34.791.835 RONALDO VASCONCELOS DE ANDRADE
# 3        LOJA:5,                                     ARCOS BAR LTDA
# 4         LOJA 5                       ARCOS BAR E RESTAURANTE LTDA
# ..           ...                                                ...
# 136          NaN                          CHURRASCARIA DO XICO LTDA
# 137          NaN        MARIA BENIGNA ARAUJO FIGUEIREDO 03809132675
# 138          NaN            ESPACO GASTRONOMICO FOGAO CANASTRA LTDA
# 139       LOJA 3                                    ZE BOLACHA LTDA
# 140          LJ.       WENDEL GOMES FERREIRA BAR E RESTAURANTE LTDA
#
#                      NOME_FANTASIA comp_completo  \
# 0                    ALEXANDRE BAR            01
# 1    BUTECO E LINGUICERIA AMARELIM
# 2                              NaN
# 3                        ARCOS BAR             5
# 4          ARCOS BAR E RESTAURANTE             5
# ..                             ...           ...
# 136              XICO DO CHURRASCO
# 137                   ER SPORT BAR
# 138                 FOGAO CANASTRA
# 139                     ZE BOLACHA             3
# 140                        ZOO BAR
#
#                     chave_completo _merge
# 0        david alves do vale|68|01   both
# 1                francisco sa|658|   both
# 2                    dona geni|32|   both
# 3                  da bahia|1144|5   both
# 4                  da bahia|1144|5   both
# ..                             ...    ...
# 136   altamiro avelino soares|920|   both
# 137   altamiro avelino soares|920|   both
# 138   altamiro avelino soares|920|   both
# 139             das melancias|35|3   both
# 140  otacilio negrao de lima|7844|   both
#
# [141 rows x 21 columns]

# %%
nomes = nomes_duplicados = df_merge['Nome'][df_merge['Nome'].duplicated()].unique()
df_repetidos = df_merge[df_merge['Nome'].isin(nomes)]


nomes_unicos = df_merge['Nome'][~df_merge['Nome'].duplicated(keep=False)]
df_match_certo = df_merge[df_merge['Nome'].isin(nomes_unicos)]
df_match_certo.to_csv("matches_quase_certos.csv", index=False, encoding="utf-8-sig")

# %%
df_merge = df_merge[[
    'ID_ATIV_ECON_ESTABELECIMENTO',
    'Nome',
    'NOME',
    'NOME_FANTASIA',
    'NOME_LOGRADOURO',
    'rua',
    'NUMERO_IMOVEL',
    'numero',
    '_merge'
]]
df_merge
# Out:
#      ID_ATIV_ECON_ESTABELECIMENTO               Nome  \
# 0                         22799.0    Alexandre’s Bar
# 1                        324006.0  Amarelim do Prado
# 2                        230593.0     Andrade’s Beer
# 3                        351721.0          Arcos Bar
# 4                        228827.0          Arcos Bar
# ..                            ...                ...
# 136                      419351.0  Xico do Churrasco
# 137                      171880.0  Xico do Churrasco
# 138                      372777.0  Xico do Churrasco
# 139                      102948.0         Zé Bolacha
# 140                       50619.0            Zoo Bar
#
#                                                   NOME  \
# 0    ALEXANDRE MOREIRA DE AZEVEDO - CPF: 047.878.19...
# 1                  JANUARIO COMERCIO DE ALIMENTOS LTDA
# 2            34.791.835 RONALDO VASCONCELOS DE ANDRADE
# 3                                       ARCOS BAR LTDA
# 4                         ARCOS BAR E RESTAURANTE LTDA
# ..                                                 ...
# 136                          CHURRASCARIA DO XICO LTDA
# 137        MARIA BENIGNA ARAUJO FIGUEIREDO 03809132675
# 138            ESPACO GASTRONOMICO FOGAO CANASTRA LTDA
# 139                                    ZE BOLACHA LTDA
# 140       WENDEL GOMES FERREIRA BAR E RESTAURANTE LTDA
#
#                      NOME_FANTASIA          NOME_LOGRADOURO  \
# 0                    ALEXANDRE BAR      DAVID ALVES DO VALE
# 1    BUTECO E LINGUICERIA AMARELIM             FRANCISCO SA
# 2                              NaN                DONA GENI
# 3                        ARCOS BAR                 DA BAHIA
# 4          ARCOS BAR E RESTAURANTE                 DA BAHIA
# ..                             ...                      ...
# 136              XICO DO CHURRASCO  ALTAMIRO AVELINO SOARES
# 137                   ER SPORT BAR  ALTAMIRO AVELINO SOARES
# 138                 FOGAO CANASTRA  ALTAMIRO AVELINO SOARES
# 139                     ZE BOLACHA            DAS MELANCIAS
# 140                        ZOO BAR  OTACILIO NEGRAO DE LIMA
#
#                          rua  NUMERO_IMOVEL numero _merge
# 0        David Alves do Vale           68.0     68   both
# 1               Francisco Sá          658.0    658   both
# 2                  Dona Geni           32.0     32   both
# 3                   da Bahia         1144.0   1144   both
# 4                   da Bahia         1144.0   1144   both
# ..                       ...            ...    ...    ...
# 136  Altamiro avelino Soares          920.0    920   both
# 137  Altamiro avelino Soares          920.0    920   both
# 138  Altamiro avelino Soares          920.0    920   both
# 139            das Melancias           35.0     35   both
# 140  Otacílio Negrão de Lima         7844.0   7844   both
#
# [141 rows x 9 columns]

# %%
df_nao_casaram = df_merge[df_merge['_merge'] == 'left_only'].copy()
df_nao_casaram
# Out:
#      ID_ATIV_ECON_ESTABELECIMENTO                        Nome NOME  \
# 23                            NaN                Bar do Romeu  NaN
# 31                            NaN                  Bar Pompéu  NaN
# 32                            NaN                  Bar Stella  NaN
# 36                            NaN                   Bazin Bar  NaN
# 37                            NaN            Beco Restaurante  NaN
# 47                            NaN                Buteco’s Bar  NaN
# 49                            NaN                  Café Bahia  NaN
# 60                            NaN  Choperia América Norte Sul  NaN
# 66                            NaN           Deck Boi na Brasa  NaN
# 72                            NaN        Espetinhos do Paulão  NaN
# 88                            NaN           Magnífico Quintal  NaN
# 90                            NaN                  Mamute Bar  NaN
# 129                           NaN                 The Butcher  NaN
#
#     NOME_FANTASIA NOME_LOGRADOURO                        rua  NUMERO_IMOVEL  \
# 23            NaN             NaN                      Aniri            NaN
# 31            NaN             NaN                 São Miguel            NaN
# 32            NaN             NaN                  Saramenha            NaN
# 36            NaN             NaN            Orozimbo Nonato            NaN
# 37            NaN             NaN                    Tamoios            NaN
# 47            NaN             NaN              Ernesto Braga            NaN
# 49            NaN             NaN                      Tupis            NaN
# 60            NaN             NaN                  Chico Rei            NaN
# 66            NaN             NaN  Desembargador José Satyro            NaN
# 72            NaN             NaN                Álvaro Mata            NaN
# 88            NaN             NaN      Jefferson de Oliveira            NaN
# 90            NaN             NaN                 Brás Cubas            NaN
# 129           NaN             NaN                    Ressaca            NaN
#
#     numero     _merge
# 23       8  left_only
# 31     779  left_only
# 32    1599  left_only
# 36    1053  left_only
# 37     232  left_only
# 47       2  left_only
# 49     369  left_only
# 60     190  left_only
# 66     302  left_only
# 72     466  left_only
# 88      56  left_only
# 90     116  left_only
# 129    353  left_only

# %%
# 1. Separar os que não casaram ainda
df_nao_casaram = df_merge[df_merge['_merge'] == 'left_only'].copy()

# 2. Normaliza os nomes
df_nao_casaram['nome_norm'] = df_nao_casaram['Nome'].apply(normaliza_texto)
df_reduzido['nome_norm'] = df_reduzido['NOME'].apply(lambda x: normaliza_texto(x) if pd.notna(x) else '')
df_reduzido['fantasia_norm'] = df_reduzido['NOME_FANTASIA'].apply(lambda x: normaliza_texto(x) if pd.notna(x) else '')

# 3. Lista de nomes normalizados únicos
nomes_possiveis = df_reduzido['nome_norm'].dropna().unique().tolist()
fantasias_possiveis = df_reduzido['fantasia_norm'].dropna().unique().tolist()

# 4. Para cada nome do buteco não casado, tentar encontrar no df_reduzido
ids_fuzzy = []

for nome in df_nao_casaram['nome_norm']:
    match = encontrar_correspondencia(nome, nomes_possiveis)
    if match:
        linha = df_reduzido[df_reduzido['nome_norm'] == match].iloc[0]
        ids_fuzzy.append(linha['ID_ATIV_ECON_ESTABELECIMENTO'])
    else:
        match = encontrar_correspondencia(nome, fantasias_possiveis)
        if match:
            linha = df_reduzido[df_reduzido['fantasia_norm'] == match].iloc[0]
            ids_fuzzy.append(linha['ID_ATIV_ECON_ESTABELECIMENTO'])
        else:
            ids_fuzzy.append(None)

# 5. Atribui os IDs fuzzy encontrados
df_nao_casaram['ID_ATIV_ECON_ESTABELECIMENTO'] = ids_fuzzy

# 6. Seleciona apenas as colunas relevantes
df_nao_casaram = df_nao_casaram[['Nome', 'ID_ATIV_ECON_ESTABELECIMENTO']]

# 7. Atualiza o df_merge original com esses novos IDs (sem criar novas colunas)
df_merge.loc[df_merge['_merge'] == 'left_only', 'ID_ATIV_ECON_ESTABELECIMENTO'] = (
    df_merge[df_merge['_merge'] == 'left_only']
    .merge(df_nao_casaram, on='Nome', how='left')['ID_ATIV_ECON_ESTABELECIMENTO_y']
)

# %%
df_merge[df_merge['ID_ATIV_ECON_ESTABELECIMENTO'].isna()]
# Out:
#      ID_ATIV_ECON_ESTABELECIMENTO                        Nome NOME  \
# 23                            NaN                Bar do Romeu  NaN
# 31                            NaN                  Bar Pompéu  NaN
# 32                            NaN                  Bar Stella  NaN
# 36                            NaN                   Bazin Bar  NaN
# 37                            NaN            Beco Restaurante  NaN
# 47                            NaN                Buteco’s Bar  NaN
# 49                            NaN                  Café Bahia  NaN
# 60                            NaN  Choperia América Norte Sul  NaN
# 66                            NaN           Deck Boi na Brasa  NaN
# 72                            NaN        Espetinhos do Paulão  NaN
# 88                            NaN           Magnífico Quintal  NaN
# 90                            NaN                  Mamute Bar  NaN
# 129                           NaN                 The Butcher  NaN
#
#     NOME_FANTASIA NOME_LOGRADOURO                        rua  NUMERO_IMOVEL  \
# 23            NaN             NaN                      Aniri            NaN
# 31            NaN             NaN                 São Miguel            NaN
# 32            NaN             NaN                  Saramenha            NaN
# 36            NaN             NaN            Orozimbo Nonato            NaN
# 37            NaN             NaN                    Tamoios            NaN
# 47            NaN             NaN              Ernesto Braga            NaN
# 49            NaN             NaN                      Tupis            NaN
# 60            NaN             NaN                  Chico Rei            NaN
# 66            NaN             NaN  Desembargador José Satyro            NaN
# 72            NaN             NaN                Álvaro Mata            NaN
# 88            NaN             NaN      Jefferson de Oliveira            NaN
# 90            NaN             NaN                 Brás Cubas            NaN
# 129           NaN             NaN                    Ressaca            NaN
#
#     numero     _merge
# 23       8  left_only
# 31     779  left_only
# 32    1599  left_only
# 36    1053  left_only
# 37     232  left_only
# 47       2  left_only
# 49     369  left_only
# 60     190  left_only
# 66     302  left_only
# 72     466  left_only
# 88      56  left_only
# 90     116  left_only
# 129    353  left_only
